# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 设置matplotlib使用支持中文的字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 加载数据
data = pd.read_excel('Attachment 1.xlsx')
data.columns = ['MJD(days)', 'PT-TT(s)']

# 设置MJD(days)为索引
data.set_index(keys='MJD(days)', inplace=True)

# 清理数据，将非数值转换为NaN并删除
data['PT-TT(s)'] = pd.to_numeric(data['PT-TT(s)'], errors='coerce')
data = data.dropna()

# 对数据进行差分处理
diff_data = data['PT-TT(s)'].diff().dropna()

# 数据标准化
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(diff_data.values.reshape(-1, 1))

# 准备LSTM的输入数据
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

# 增加序列长度以捕捉更长期的模式
seq_length = 120  # 从90增加到120天
X, y = create_sequences(scaled_data, seq_length)

# 划分训练集和测试集
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 重塑数据以适应LSTM输入格式 [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# 构建更复杂的双向LSTM模型
model = Sequential([
    Bidirectional(LSTM(256, activation='relu', return_sequences=True), input_shape=(seq_length, 1)),
    Dropout(0.4),
    Bidirectional(LSTM(128, activation='relu', return_sequences=True)),
    Dropout(0.4),
    Bidirectional(LSTM(64, activation='relu')),
    Dropout(0.4),
    Dense(32, activation='relu'),
    Dense(1)
])

# 编译模型，使用更小的学习率以提高稳定性
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')

# 训练模型，增加epochs
history = model.fit(X_train, y_train, epochs=300, batch_size=16, 
                   validation_split=0.1, verbose=1)

# 预测训练数据
train_pred = model.predict(X_train)
train_pred = scaler.inverse_transform(train_pred)

# 预测未来365天
last_sequence = scaled_data[-seq_length:]
predictions = []

for _ in range(365):
    # 重塑数据用于预测
    current_sequence = last_sequence.reshape(1, seq_length, 1)
    # 预测下一个值
    next_pred = model.predict(current_sequence, verbose=0)[0]
    # 确保预测值在[0,1]范围内
    next_pred = np.clip(next_pred, 0, 1)
    # 添加预测值到列表
    predictions.append(next_pred[0])
    # 更新序列
    last_sequence = np.append(last_sequence[1:], next_pred)

# 反向转换预测值
predictions = np.array(predictions).reshape(-1, 1)
predictions = np.clip(predictions, 0, 1)  # 再次确保所有值都在[0,1]范围内
predictions = scaler.inverse_transform(predictions)

# 将差分预测值转换回原始值
original_last_value = data['PT-TT(s)'].iloc[-1]
cumsum_predictions = np.cumsum(predictions)
final_predictions = cumsum_predictions + original_last_value

# 创建预测索引
forecast_index = data.index[-1] + np.arange(1, 366)

# 保存预测结果
forecast_df = pd.DataFrame({
    'MJD(days)': forecast_index,
    'Predicted PT-TT(s)': final_predictions.flatten()
})
forecast_df.to_csv('LSTM长期预测结果.csv', index=False, encoding='utf-8-sig')

# 绘制结果
plt.figure(figsize=(12, 8))

# 绘制历史数据
plt.plot(data.index, data['PT-TT(s)'], label='历史噪声数据', color='blue', linewidth=2)

# 绘制训练数据的拟合结果
train_index = data.index[seq_length:seq_length+len(train_pred)]
cumsum_train_pred = np.cumsum(train_pred.flatten())
final_train_pred = cumsum_train_pred + data['PT-TT(s)'].iloc[seq_length-1]
plt.plot(train_index, final_train_pred, label='训练数据拟合', color='green', linewidth=2)

# 绘制预测结果
plt.plot(forecast_index, final_predictions, label='LSTM长期预测（365天）', color='red', linestyle='--', linewidth=2)

plt.xlabel('MJD(days)')
plt.ylabel('PT-TT(s)')
plt.title('脉冲星计时噪声的LSTM长期预测（差分处理）')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# 绘制训练过程中的损失变化
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='训练损失')
plt.plot(history.history['val_loss'], label='验证损失')
plt.title('模型训练过程中的损失变化')
plt.xlabel('Epoch')
plt.ylabel('损失值')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/300
# C:\Users\tk\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - loss: 0.1001 - val_loss: 0.0707
# Epoch 2/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0306 - val_loss: 0.0066
# Epoch 3/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0080 - val_loss: 0.0058
# Epoch 4/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 5/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 6/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0046 - val_loss: 0.0066
# Epoch 7/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0047 - val_loss: 0.0060
# Epoch 8/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.0043 - val_loss: 0.0057
# Epoch 9/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 10/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0042 - val_loss: 0.0072
# Epoch 11/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 12/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 13/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0042 - val_loss: 0.0061
# Epoch 14/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0042 - val_loss: 0.0052
# Epoch 15/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 16/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0047 - val_loss: 0.0060
# Epoch 17/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 18/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 19/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 20/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 21/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 22/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0029 - val_loss: 0.0052
# Epoch 23/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0038 - val_loss: 0.0053
# Epoch 24/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 25/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 26/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 27/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0043 - val_loss: 0.0066
# Epoch 28/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0037 - val_loss: 0.0071
# Epoch 29/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 30/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 31/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 32/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 33/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 34/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 35/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 36/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0031 - val_loss: 0.0062
# Epoch 37/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 38/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 39/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0033 - val_loss: 0.0046
# Epoch 40/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 41/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 42/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 43/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 44/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 45/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 46/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 47/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 48/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0035 - val_loss: 0.0060
# Epoch 49/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 50/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 51/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 52/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0029 - val_loss: 0.0047
# Epoch 53/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0036 - val_loss: 0.0051
# Epoch 54/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 55/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 56/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 57/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 58/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 59/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 60/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0031 - val_loss: 0.0052
# Epoch 61/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 62/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 63/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 64/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0033 - val_loss: 0.0046
# Epoch 65/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0028 - val_loss: 0.0041
# Epoch 66/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 67/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0026 - val_loss: 0.0049
# Epoch 68/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 69/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 70/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0030 - val_loss: 0.0056
# Epoch 71/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 72/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 73/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 74/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0028 - val_loss: 0.0055
# Epoch 75/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0027 - val_loss: 0.0051
# Epoch 76/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 77/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 78/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 79/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 80/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 81/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 82/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 83/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 84/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0025 - val_loss: 0.0049
# Epoch 85/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 86/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 87/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0024 - val_loss: 0.0046
# Epoch 88/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 89/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 90/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 91/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 92/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 93/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 94/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 95/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 96/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 97/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0026 - val_loss: 0.0051
# Epoch 98/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 99/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 100/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 101/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 102/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 103/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 104/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0026 - val_loss: 0.0055
# Epoch 105/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 106/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 107/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 108/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 109/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 110/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 111/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 112/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0027 - val_loss: 0.0054
# Epoch 113/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0033 - val_loss: 0.0060
# Epoch 114/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 115/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 116/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 117/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 118/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 119/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 120/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 121/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 122/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 123/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 124/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 125/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 126/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 127/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 128/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 129/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 130/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 131/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 132/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 133/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 134/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 135/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 136/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 137/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 138/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 139/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 140/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 141/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 142/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 143/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 144/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 145/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 146/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 147/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 148/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 149/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 150/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 151/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 152/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 153/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 154/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 155/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 156/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 157/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 158/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 159/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 160/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 161/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 162/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 163/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 164/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 165/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 166/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 167/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 168/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 169/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 170/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 171/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 172/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 173/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 174/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 175/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 176/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 177/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 178/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 179/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 180/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 181/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 182/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 183/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 184/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 185/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 186/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 187/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 188/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 189/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 190/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 191/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 192/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 193/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 194/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 195/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 196/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 197/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 198/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 199/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 200/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 201/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 202/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 203/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 204/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 205/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 206/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 207/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 208/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 209/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 210/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 211/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 212/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 213/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 214/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 215/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 216/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 217/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 218/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 219/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 220/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 221/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 222/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 223/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 224/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 225/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0018 - val_loss: 0.0036
# Epoch 226/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 227/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 228/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 229/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 230/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 231/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 232/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 233/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 234/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 235/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 236/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 237/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 238/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 239/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 240/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 241/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 242/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 243/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 244/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 245/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 246/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 247/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 248/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 249/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 250/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 251/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 252/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 253/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 254/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 255/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 256/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 257/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 258/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 259/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 260/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 261/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 262/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 263/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 264/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 265/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 266/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 267/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 268/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 269/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 270/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 271/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 272/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 273/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 274/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 275/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 276/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 277/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 278/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 279/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 280/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 281/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 282/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 283/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 284/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 285/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 286/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 287/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 288/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 289/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 290/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 291/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 292/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 293/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 294/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 295/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 296/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 297/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 298/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 299/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 300/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0020 - val_loss: 0.0036
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
