# %%
from shapes import Triangle, Shape
from hexshapes import Hexagon, HShape
from shapes import hexagon_maker as hexmaker
from shapes import triangle_of_hexes as toh
from hexshapes import bighex_maker as bhmaker
import time

def data_writer(base, type = "corona"):
    with open('./plotlist.txthexagon testing-1', 'w') as file:
        if type == "heesch":
            coronalist = base.heesch_computer()[0]
            coronadata = []
            for corona_config in coronalist:
                coronadata.append([shape.to_data() for shape in corona_config])
            datadict = {"type": type, "num": len(coronalist), "data": {"base": base.to_data(), "heesch": coronadata}}

        elif type == "corona2":
            coronalist = base.second_corona()[0]
            first_data = []
            for shape in coronalist["first"]:
                first_data.append(shape.to_data())
            second_data = []
            for shape in coronalist["second"][0]:
                second_data.append(shape.to_data())
            datadict = {"type": type, "data": {"base": base.to_data(), "first": first_data, "second": second_data}}

        elif type == "corona":
            coronalist = base.corona_maker(base.orientations())[0]
            corona_data = []
            for shape in coronalist:
                corona_data.append(shape.to_data())
            datadict = {"type": type, "data": {"base": base.to_data(), "corona": corona_data}}

        elif type == "base":
            datadict = {"type": type, "data": {"base": base.to_data()}}

        file.write(str(datadict))

start_time = time.time()

""" Some testing shapes"""
S1 = Shape(toh())
# S1 = Shape(toh() + hexmaker(2,-5) + hexmaker(5, -2) + hexmaker(6, -3))
# S1 = Shape([triangle for triangle in toh() if triangle not in hexmaker(3,-3)+hexmaker(2,-2)])
# S1 = Shape([triangle for triangle in hexmaker(0,0)+[Triangle(1,1)] if triangle not in [Triangle(0,0)]])
# S1 = Shape(hexmaker(-1,1)+hexmaker(1,2)+hexmaker(2,1)+hexmaker(1,-1)+hexmaker(-1,-2))


""" edge data testing """
# S1 = HShape([Hexagon(0,0, [1, 1, 1, 0, -1, -1])])

"""4hex H2
takes too long"""

# priority = [
# Hexagon(-1, 1),
# Hexagon(1, 2),
# ]
#
# S1 = HShape([
# Hexagon(0, 0, [0, 0, 0, 1, -1, 0]),
# Hexagon(1, -1),
# Hexagon(2, 1),
# Hexagon(3, 0),
# ],
# priority = priority
# )

"""3hex H2
computes in 13 sec"""

# S1 = HShape(
# [Hexagon(0, 0, [0, 0, 0, -1, 0, -1]),
# Hexagon(2, 1, [0, 0, 1, 0, 0, 0]),
# Hexagon(1, -1)],
#
# )

""" 2-hexapillar
computes in 323 sec"""
# S1 = HShape(
# [Hexagon(0, 0, [1, 1, 0, -1, -1, 0]),
# Hexagon(2, 1, [1, 1, -1, -1, -1, 0])],

# )

# H1 = Hexagon(0, 0, [1, 0, 0, 0, 0, 0])
# H2 = Hexagon(1, 2, [0, 0, -1, 0, 0, 0])
# S1 = HShape([H1, H2])

# S1 = HShape([
# Hexagon(0, 0, [0, 0, 0, 0, -1, 0]),
# Hexagon(1, -1, [0, 0, 0, 0, 0, 1]),
# Hexagon(2, 1),
# Hexagon(3, 0),
# Hexagon(0, -3),
# ])

""" hexagon testing """
# S1 = HShape( [Hexagon(0,0), Hexagon(2,1), Hexagon(3,0)])
# S1 = HShape( [hex for hex in bhmaker(0,0) if hex not in [Hexagon(-2,-1), Hexagon(0,0)] ]  )
# S1 = HShape( bhmaker(0,0)+[Hexagon(-2,2), Hexagon(-2,-4), Hexagon(4,2), Hexagon(0,-3), Hexagon(3,0), Hexagon(4,-1)] )


""" This has types:
    1) Corona
    2) Boundary
    3) Base
"""
data_writer(S1, type = "heesch")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# test: we are now at 12%
# 2
# test: we are now at 25%
# 9
# test: we are now at 37%
# 5
# test: we are now at 50%
# 31
# test: we are now at 62%
# 19
# test: we are now at 75%
# 18
# test: we are now at 87%
# 48
# test: we are now at 100%
# 36
#
#                 --------------------------------------
#                 We are now computing the 2nd corona
#                 --------------------------------------
#
#  heesch_corona:we are now at 2%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 16%
# 2
# test: we are now at 22%
# 1
# test: we are now at 27%
# 7
# test: we are now at 33%
# 4
# test: we are now at 38%
#  heesch_corona:we are now at 5%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 16%
# 2
# test: we are now at 22%
# 1
# test: we are now at 27%
# 7
# test: we are now at 33%
# 4
# test: we are now at 38%
# 6
# test: we are now at 44%
# 36
# test: we are now at 50%
# 18
# test: we are now at 55%
# 48
# test: we are now at 61%
# 36
# test: we are now at 66%
# 54
# test: we are now at 72%
# 54
# test: we are now at 77%
# 54
# test: we are now at 83%
# 189
# test: we are now at 88%
# 162
# test: we are now at 94%
# 108
# test: we are now at 100%
# 54
#  heesch_corona:we are now at 8%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 14
# test: we are now at 21%
# 4
# test: we are now at 26%
# 2
# test: we are now at 31%
# 14
# test: we are now at 36%
# 8
# test: we are now at 42%
#  heesch_corona:we are now at 11%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 17%
# 14
# test: we are now at 23%
# 4
# test: we are now at 29%
# 2
# test: we are now at 35%
# 14
# test: we are now at 41%
# 8
# test: we are now at 47%
#  heesch_corona:we are now at 13%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 14
# test: we are now at 21%
# 4
# test: we are now at 26%
# 2
# test: we are now at 31%
# 14
# test: we are now at 36%
# 8
# test: we are now at 42%
#  heesch_corona:we are now at 16%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 14
# test: we are now at 21%
# 4
# test: we are now at 26%
# 2
# test: we are now at 31%
# 14
# test: we are now at 36%
# 8
# test: we are now at 42%
# 12
# test: we are now at 47%
# 12
# test: we are now at 52%
#  heesch_corona:we are now at 19%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 17%
# 14
# test: we are now at 23%
# 4
# test: we are now at 29%
# 2
# test: we are now at 35%
# 14
# test: we are now at 41%
# 8
# test: we are now at 47%
# 12
# test: we are now at 52%
# 72
# test: we are now at 58%
# 36
# test: we are now at 64%
# 36
# test: we are now at 70%
# 36
# test: we are now at 76%
# 126
# test: we are now at 82%
# 108
# test: we are now at 88%
# 180
# test: we are now at 94%
# 108
# test: we are now at 100%
# 72
#  heesch_corona:we are now at 22%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 14
# test: we are now at 21%
# 4
# test: we are now at 26%
# 2
# test: we are now at 31%
# 14
# test: we are now at 36%
# 8
# test: we are now at 42%
# 12
# test: we are now at 47%
# 12
# test: we are now at 52%
#  heesch_corona:we are now at 25%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 16%
# 2
# test: we are now at 22%
# 1
# test: we are now at 27%
# 7
# test: we are now at 33%
# 4
# test: we are now at 38%
#  heesch_corona:we are now at 27%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 2
# test: we are now at 21%
# 1
# test: we are now at 26%
# 7
# test: we are now at 31%
# 4
# test: we are now at 36%
#  heesch_corona:we are now at 30%
# test: we are now at 5%
# 11
# test: we are now at 11%
# 7
# test: we are now at 16%
# 2
# test: we are now at 22%
# 1
# test: we are now at 27%
# 7
# test: we are now at 33%
# 4
# test: we are now at 38%
# 6
# test: we are now at 44%
# 18
# test: we are now at 50%
# 6
# test: we are now at 55%
# 12
# test: we are now at 61%
#  heesch_corona:we are now at 33%
# test: we are now at 5%
# 11
# test: we are now at 10%
# 7
# test: we are now at 15%
# 2
# test: we are now at 21%
# 1
# test: we are now at 26%
# 7
# test: we are now at 31%
# 4
# test: we are now at 36%
# 6
# test: we are now at 42%
# 18
# test: we are now at 47%
# 6
# test: we are now at 52%
#  heesch_corona:we are now at 36%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 21%
# 6
# test: we are now at 26%
# 3
# test: we are now at 31%
# 8
# test: we are now at 36%
# 6
# test: we are now at 42%
# 9
# test: we are now at 47%
#  heesch_corona:we are now at 38%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 21%
# 6
# test: we are now at 26%
# 3
# test: we are now at 31%
# 8
# test: we are now at 36%
# 6
# test: we are now at 42%
# 9
# test: we are now at 47%
# 9
# test: we are now at 52%
# 54
# test: we are now at 57%
# 27
# test: we are now at 63%
# 72
# test: we are now at 68%
# 54
# test: we are now at 73%
# 81
# test: we are now at 78%
# 81
# test: we are now at 84%
# 81
# test: we are now at 89%
# 162
# test: we are now at 94%
# 108
# test: we are now at 100%
# 54
#  heesch_corona:we are now at 41%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 4
# test: we are now at 20%
# 2
# test: we are now at 25%
# 12
# test: we are now at 30%
# 6
# test: we are now at 35%
# 16
# test: we are now at 40%
# 12
# test: we are now at 45%
# 18
# test: we are now at 50%
#  heesch_corona:we are now at 44%
# test: we are now at 5%
# 10
# test: we are now at 11%
# 2
# test: we are now at 16%
# 4
# test: we are now at 22%
# 2
# test: we are now at 27%
# 12
# test: we are now at 33%
# 6
# test: we are now at 38%
# 16
# test: we are now at 44%
# 12
# test: we are now at 50%
# 18
# test: we are now at 55%
#  heesch_corona:we are now at 47%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 4
# test: we are now at 20%
# 2
# test: we are now at 25%
# 12
# test: we are now at 30%
# 6
# test: we are now at 35%
# 16
# test: we are now at 40%
# 12
# test: we are now at 45%
# 18
# test: we are now at 50%
#  heesch_corona:we are now at 50%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 4
# test: we are now at 20%
# 2
# test: we are now at 25%
# 12
# test: we are now at 30%
# 6
# test: we are now at 35%
# 16
# test: we are now at 40%
# 12
# test: we are now at 45%
# 18
# test: we are now at 50%
# 18
# test: we are now at 55%
# 18
# test: we are now at 60%
#  heesch_corona:we are now at 52%
# test: we are now at 5%
# 10
# test: we are now at 11%
# 2
# test: we are now at 16%
# 4
# test: we are now at 22%
# 2
# test: we are now at 27%
# 12
# test: we are now at 33%
# 6
# test: we are now at 38%
# 16
# test: we are now at 44%
# 12
# test: we are now at 50%
# 18
# test: we are now at 55%
# 18
# test: we are now at 61%
# 108
# test: we are now at 66%
# 54
# test: we are now at 72%
# 54
# test: we are now at 77%
# 54
# test: we are now at 83%
# 108
# test: we are now at 88%
# 180
# test: we are now at 94%
# 108
# test: we are now at 100%
# 72
#  heesch_corona:we are now at 55%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 4
# test: we are now at 20%
# 2
# test: we are now at 25%
# 12
# test: we are now at 30%
# 6
# test: we are now at 35%
# 16
# test: we are now at 40%
# 12
# test: we are now at 45%
# 18
# test: we are now at 50%
# 18
# test: we are now at 55%
# 18
# test: we are now at 60%
#  heesch_corona:we are now at 58%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 21%
# 6
# test: we are now at 26%
# 3
# test: we are now at 31%
# 8
# test: we are now at 36%
# 6
# test: we are now at 42%
# 9
# test: we are now at 47%
#  heesch_corona:we are now at 61%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 20%
# 6
# test: we are now at 25%
# 3
# test: we are now at 30%
# 8
# test: we are now at 35%
# 6
# test: we are now at 40%
# 9
# test: we are now at 45%
#  heesch_corona:we are now at 63%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 21%
# 6
# test: we are now at 26%
# 3
# test: we are now at 31%
# 8
# test: we are now at 36%
# 6
# test: we are now at 42%
# 9
# test: we are now at 47%
# 9
# test: we are now at 52%
# 27
# test: we are now at 57%
# 9
# test: we are now at 63%
# 18
# test: we are now at 68%
#  heesch_corona:we are now at 66%
# test: we are now at 5%
# 10
# test: we are now at 10%
# 2
# test: we are now at 15%
# 1
# test: we are now at 20%
# 6
# test: we are now at 25%
# 3
# test: we are now at 30%
# 8
# test: we are now at 35%
# 6
# test: we are now at 40%
# 9
# test: we are now at 45%
# 9
# test: we are now at 50%
# 27
# test: we are now at 55%
# 9
# test: we are now at 60%
#  heesch_corona:we are now at 69%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#  heesch_corona:we are now at 72%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#  heesch_corona:we are now at 75%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
# 6
# test: we are now at 20%
#  heesch_corona:we are now at 77%
# test: we are now at 5%
# 9
# test: we are now at 11%
# 3
# test: we are now at 16%
# 6
# test: we are now at 22%
#  heesch_corona:we are now at 80%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
# 6
# test: we are now at 20%
#  heesch_corona:we are now at 83%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
# 6
# test: we are now at 20%
#  heesch_corona:we are now at 86%
# test: we are now at 5%
# 9
# test: we are now at 11%
# 3
# test: we are now at 16%
# 6
# test: we are now at 22%
#  heesch_corona:we are now at 88%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
# 6
# test: we are now at 20%
#  heesch_corona:we are now at 91%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#  heesch_corona:we are now at 94%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#  heesch_corona:we are now at 97%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#  heesch_corona:we are now at 100%
# test: we are now at 5%
# 9
# test: we are now at 10%
# 3
# test: we are now at 15%
#
#                 --------------------------------------
#                 We are now computing the 3nd corona
#                 --------------------------------------
#
#  heesch_corona:we are now at 0%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 0%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 1%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 7
# test: we are now at 32%
# 4
# test: we are now at 35%
#  heesch_corona:we are now at 1%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 7
# test: we are now at 32%
# 4
# test: we are now at 35%
#  heesch_corona:we are now at 1%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 3
# test: we are now at 20%
# 1
# test: we are now at 23%
# 1
# test: we are now at 26%
# 7
# test: we are now at 30%
# 4
# test: we are now at 33%
#  heesch_corona:we are now at 2%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 3
# test: we are now at 20%
# 1
# test: we are now at 23%
# 1
# test: we are now at 26%
# 7
# test: we are now at 30%
# 4
# test: we are now at 33%
#  heesch_corona:we are now at 2%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 3%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 3%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 3
# test: we are now at 20%
# 1
# test: we are now at 23%
# 1
# test: we are now at 26%
# 7
# test: we are now at 30%
# 4
# test: we are now at 33%
#  heesch_corona:we are now at 3%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 3
# test: we are now at 20%
# 1
# test: we are now at 23%
# 1
# test: we are now at 26%
# 7
# test: we are now at 30%
# 4
# test: we are now at 33%
#  heesch_corona:we are now at 4%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 4%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
#  heesch_corona:we are now at 5%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 7
# test: we are now at 32%
# 4
# test: we are now at 35%
# 6
# test: we are now at 39%
# 6
# test: we are now at 42%
# 9
# test: we are now at 46%
# 54
# test: we are now at 50%
# 27
# test: we are now at 53%
# 72
# test: we are now at 57%
# 54
# test: we are now at 60%
# 81
# test: we are now at 64%
# 81
# test: we are now at 67%
# 54
# test: we are now at 71%
# 54
# test: we are now at 75%
# 54
# test: we are now at 78%
# 54
# test: we are now at 82%
# 36
# test: we are now at 85%
# 36
# test: we are now at 89%
# 36
# test: we are now at 92%
# 36
# test: we are now at 96%
# 54
# test: we are now at 100%
# 54
#  heesch_corona:we are now at 5%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 7
# test: we are now at 32%
# 4
# test: we are now at 35%
# 6
# test: we are now at 39%
# 6
# test: we are now at 42%
# 9
# test: we are now at 46%
# 54
# test: we are now at 50%
# 27
# test: we are now at 53%
# 72
# test: we are now at 57%
# 54
# test: we are now at 60%
# 81
# test: we are now at 64%
# 81
# test: we are now at 67%
# 54
# test: we are now at 71%
#  heesch_corona:we are now at 5%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
# 6
# test: we are now at 37%
# 6
# test: we are now at 41%
# 9
# test: we are now at 44%
# 54
# test: we are now at 48%
# 27
# test: we are now at 51%
# 45
# test: we are now at 55%
# 27
# test: we are now at 58%
# 18
# test: we are now at 62%
# 9
# test: we are now at 65%
# 9
# test: we are now at 68%
#  heesch_corona:we are now at 6%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
# 6
# test: we are now at 37%
# 6
# test: we are now at 41%
# 9
# test: we are now at 44%
# 54
# test: we are now at 48%
# 27
# test: we are now at 51%
# 45
# test: we are now at 55%
# 27
# test: we are now at 58%
# 18
# test: we are now at 62%
# 9
# test: we are now at 65%
# 9
# test: we are now at 68%
#  heesch_corona:we are now at 6%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
# 6
# test: we are now at 37%
# 6
# test: we are now at 41%
# 9
# test: we are now at 44%
# 54
# test: we are now at 48%
# 27
# test: we are now at 51%
# 45
# test: we are now at 55%
# 27
# test: we are now at 58%
# 18
# test: we are now at 62%
# 27
# test: we are now at 65%
# 27
# test: we are now at 68%
# 36
# test: we are now at 72%
# 54
# test: we are now at 75%
# 54
# test: we are now at 79%
# 36
# test: we are now at 82%
# 36
# test: we are now at 86%
# 36
# test: we are now at 89%
# 36
# test: we are now at 93%
# 54
# test: we are now at 96%
# 54
# test: we are now at 100%
# 54
#  heesch_corona:we are now at 7%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 1
# test: we are now at 27%
# 7
# test: we are now at 31%
# 4
# test: we are now at 34%
# 6
# test: we are now at 37%
# 6
# test: we are now at 41%
# 9
# test: we are now at 44%
# 54
# test: we are now at 48%
# 27
# test: we are now at 51%
# 45
# test: we are now at 55%
# 27
# test: we are now at 58%
# 18
# test: we are now at 62%
# 27
# test: we are now at 65%
# 27
# test: we are now at 68%
# 36
# test: we are now at 72%
# 54
# test: we are now at 75%
# 54
# test: we are now at 79%
# 36
# test: we are now at 82%
# 36
# test: we are now at 86%
# 36
# test: we are now at 89%
# 72
# test: we are now at 93%
#  heesch_corona:we are now at 7%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 7%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 8%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 12
# test: we are now at 27%
# 6
# test: we are now at 31%
# 12
# test: we are now at 34%
# 8
# test: we are now at 37%
# 12
# test: we are now at 41%
#  heesch_corona:we are now at 8%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 12
# test: we are now at 27%
# 6
# test: we are now at 31%
# 12
# test: we are now at 34%
# 8
# test: we are now at 37%
# 12
# test: we are now at 41%
#  heesch_corona:we are now at 9%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 3
# test: we are now at 12%
# 3
# test: we are now at 16%
# 2
# test: we are now at 19%
# 2
# test: we are now at 22%
# 12
# test: we are now at 25%
# 6
# test: we are now at 29%
# 12
# test: we are now at 32%
# 8
# test: we are now at 35%
# 12
# test: we are now at 38%
#  heesch_corona:we are now at 9%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 3
# test: we are now at 12%
# 3
# test: we are now at 16%
# 2
# test: we are now at 19%
# 2
# test: we are now at 22%
# 12
# test: we are now at 25%
# 6
# test: we are now at 29%
# 12
# test: we are now at 32%
# 8
# test: we are now at 35%
# 12
# test: we are now at 38%
#  heesch_corona:we are now at 9%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 10%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 10%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 3
# test: we are now at 12%
# 3
# test: we are now at 16%
# 2
# test: we are now at 19%
# 2
# test: we are now at 22%
# 12
# test: we are now at 25%
# 6
# test: we are now at 29%
# 12
# test: we are now at 32%
# 8
# test: we are now at 35%
# 12
# test: we are now at 38%
#  heesch_corona:we are now at 11%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 3
# test: we are now at 12%
# 3
# test: we are now at 16%
# 2
# test: we are now at 19%
# 2
# test: we are now at 22%
# 12
# test: we are now at 25%
# 6
# test: we are now at 29%
# 12
# test: we are now at 32%
# 8
# test: we are now at 35%
# 12
# test: we are now at 38%
#  heesch_corona:we are now at 11%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 11%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
#  heesch_corona:we are now at 12%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 12
# test: we are now at 27%
# 6
# test: we are now at 31%
# 12
# test: we are now at 34%
# 8
# test: we are now at 37%
# 12
# test: we are now at 41%
# 12
# test: we are now at 44%
# 12
# test: we are now at 48%
# 72
# test: we are now at 51%
# 36
# test: we are now at 55%
# 96
# test: we are now at 58%
# 72
# test: we are now at 62%
# 108
# test: we are now at 65%
# 108
# test: we are now at 68%
# 72
# test: we are now at 72%
# 72
# test: we are now at 75%
# 72
# test: we are now at 79%
# 72
# test: we are now at 82%
# 72
# test: we are now at 86%
# 144
# test: we are now at 89%
# 144
# test: we are now at 93%
# 144
# test: we are now at 96%
# 216
# test: we are now at 100%
# 216
#  heesch_corona:we are now at 12%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 12
# test: we are now at 27%
# 6
# test: we are now at 31%
# 12
# test: we are now at 34%
# 8
# test: we are now at 37%
# 12
# test: we are now at 41%
# 12
# test: we are now at 44%
# 12
# test: we are now at 48%
# 72
# test: we are now at 51%
# 36
# test: we are now at 55%
# 96
# test: we are now at 58%
# 72
# test: we are now at 62%
# 108
# test: we are now at 65%
# 108
# test: we are now at 68%
# 72
# test: we are now at 72%
#  heesch_corona:we are now at 13%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
# 12
# test: we are now at 43%
# 12
# test: we are now at 46%
# 72
# test: we are now at 50%
# 36
# test: we are now at 53%
# 60
# test: we are now at 56%
# 36
# test: we are now at 60%
# 24
# test: we are now at 63%
# 12
# test: we are now at 66%
# 12
# test: we are now at 70%
#  heesch_corona:we are now at 13%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
# 12
# test: we are now at 43%
# 12
# test: we are now at 46%
# 72
# test: we are now at 50%
# 36
# test: we are now at 53%
# 60
# test: we are now at 56%
# 36
# test: we are now at 60%
# 24
# test: we are now at 63%
# 12
# test: we are now at 66%
# 12
# test: we are now at 70%
#  heesch_corona:we are now at 13%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
# 12
# test: we are now at 43%
# 12
# test: we are now at 46%
# 72
# test: we are now at 50%
# 36
# test: we are now at 53%
# 60
# test: we are now at 56%
# 36
# test: we are now at 60%
# 24
# test: we are now at 63%
# 36
# test: we are now at 66%
# 36
# test: we are now at 70%
# 48
# test: we are now at 73%
# 72
# test: we are now at 76%
# 72
# test: we are now at 80%
# 72
# test: we are now at 83%
# 144
# test: we are now at 86%
# 144
# test: we are now at 90%
# 144
# test: we are now at 93%
# 216
# test: we are now at 96%
# 216
# test: we are now at 100%
# 216
#  heesch_corona:we are now at 14%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 2
# test: we are now at 23%
# 12
# test: we are now at 26%
# 6
# test: we are now at 30%
# 12
# test: we are now at 33%
# 8
# test: we are now at 36%
# 12
# test: we are now at 40%
# 12
# test: we are now at 43%
# 12
# test: we are now at 46%
# 72
# test: we are now at 50%
# 36
# test: we are now at 53%
# 60
# test: we are now at 56%
# 36
# test: we are now at 60%
# 24
# test: we are now at 63%
# 36
# test: we are now at 66%
# 36
# test: we are now at 70%
# 48
# test: we are now at 73%
# 72
# test: we are now at 76%
# 72
# test: we are now at 80%
# 72
# test: we are now at 83%
# 144
# test: we are now at 86%
# 144
# test: we are now at 90%
# 288
# test: we are now at 93%
#  heesch_corona:we are now at 14%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 15%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 15%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 15%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 16%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 1
# test: we are now at 12%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 16%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 1
# test: we are now at 12%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 17%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 17%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 17%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 1
# test: we are now at 12%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 18%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 9%
# 1
# test: we are now at 12%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 18%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 19%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 19%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 19%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 20%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 20%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 21%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 21%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 21%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
#  heesch_corona:we are now at 22%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
#  heesch_corona:we are now at 22%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
#  heesch_corona:we are now at 23%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
#  heesch_corona:we are now at 23%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
#  heesch_corona:we are now at 23%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
#  heesch_corona:we are now at 24%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
#  heesch_corona:we are now at 24%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
#  heesch_corona:we are now at 25%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
#  heesch_corona:we are now at 25%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
#  heesch_corona:we are now at 25%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
#  heesch_corona:we are now at 26%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
#  heesch_corona:we are now at 26%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
#  heesch_corona:we are now at 26%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
#  heesch_corona:we are now at 27%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
#  heesch_corona:we are now at 27%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
#  heesch_corona:we are now at 28%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 28%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 28%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 29%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 29%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
#  heesch_corona:we are now at 30%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
#  heesch_corona:we are now at 30%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 30%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
#  heesch_corona:we are now at 31%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 31%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 32%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 1
# test: we are now at 14%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 32%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 1
# test: we are now at 14%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 32%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 33%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 16%
#  heesch_corona:we are now at 33%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 34%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 34%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 1
# test: we are now at 14%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 34%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 1
# test: we are now at 14%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 35%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 35%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 1
# test: we are now at 13%
# 1
# test: we are now at 17%
#  heesch_corona:we are now at 36%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 2
# test: we are now at 32%
# 3
# test: we are now at 35%
# 3
# test: we are now at 39%
# 21
# test: we are now at 42%
# 12
# test: we are now at 46%
#  heesch_corona:we are now at 36%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 1
# test: we are now at 28%
# 2
# test: we are now at 32%
# 3
# test: we are now at 35%
# 3
# test: we are now at 39%
# 21
# test: we are now at 42%
# 12
# test: we are now at 46%
#  heesch_corona:we are now at 36%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
# 2
# test: we are now at 33%
# 3
# test: we are now at 37%
# 3
# test: we are now at 40%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
#  heesch_corona:we are now at 37%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
# 2
# test: we are now at 33%
# 3
# test: we are now at 37%
# 3
# test: we are now at 40%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
#  heesch_corona:we are now at 37%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 2
# test: we are now at 27%
# 2
# test: we are now at 31%
# 2
# test: we are now at 34%
# 3
# test: we are now at 37%
# 3
# test: we are now at 41%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
#  heesch_corona:we are now at 38%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 3
# test: we are now at 20%
# 1
# test: we are now at 24%
# 2
# test: we are now at 27%
# 2
# test: we are now at 31%
# 2
# test: we are now at 34%
# 3
# test: we are now at 37%
# 3
# test: we are now at 41%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
#  heesch_corona:we are now at 38%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 2
# test: we are now at 28%
# 2
# test: we are now at 32%
# 2
# test: we are now at 35%
# 3
# test: we are now at 39%
# 3
# test: we are now at 42%
# 21
# test: we are now at 46%
# 12
# test: we are now at 50%
#  heesch_corona:we are now at 38%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 2
# test: we are now at 28%
# 2
# test: we are now at 32%
# 2
# test: we are now at 35%
# 3
# test: we are now at 39%
# 3
# test: we are now at 42%
# 21
# test: we are now at 46%
# 12
# test: we are now at 50%
#  heesch_corona:we are now at 39%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
# 2
# test: we are now at 33%
# 3
# test: we are now at 37%
# 3
# test: we are now at 40%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
# 18
# test: we are now at 51%
# 18
# test: we are now at 55%
# 27
# test: we are now at 59%
# 162
# test: we are now at 62%
# 45
# test: we are now at 66%
# 162
# test: we are now at 70%
# 108
# test: we are now at 74%
# 81
# test: we are now at 77%
# 162
# test: we are now at 81%
# 108
# test: we are now at 85%
# 72
# test: we are now at 88%
# 72
# test: we are now at 92%
# 72
# test: we are now at 96%
# 72
# test: we are now at 100%
# 36
#  heesch_corona:we are now at 39%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 11%
# 3
# test: we are now at 14%
# 3
# test: we are now at 18%
# 3
# test: we are now at 22%
# 1
# test: we are now at 25%
# 1
# test: we are now at 29%
# 2
# test: we are now at 33%
# 3
# test: we are now at 37%
# 3
# test: we are now at 40%
# 21
# test: we are now at 44%
# 12
# test: we are now at 48%
# 18
# test: we are now at 51%
# 18
# test: we are now at 55%
# 27
# test: we are now at 59%
# 162
# test: we are now at 62%
# 45
# test: we are now at 66%
# 162
# test: we are now at 70%
# 108
# test: we are now at 74%
# 81
# test: we are now at 77%
#  heesch_corona:we are now at 40%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 2
# test: we are now at 28%
# 2
# test: we are now at 32%
# 2
# test: we are now at 35%
# 3
# test: we are now at 39%
# 3
# test: we are now at 42%
# 21
# test: we are now at 46%
# 12
# test: we are now at 50%
# 18
# test: we are now at 53%
# 18
# test: we are now at 57%
# 27
# test: we are now at 60%
# 162
# test: we are now at 64%
# 81
# test: we are now at 67%
# 81
# test: we are now at 71%
# 54
# test: we are now at 75%
# 54
# test: we are now at 78%
# 54
# test: we are now at 82%
# 54
# test: we are now at 85%
# 108
# test: we are now at 89%
# 378
# test: we are now at 92%
# 126
# test: we are now at 96%
# 90
# test: we are now at 100%
# 54
#  heesch_corona:we are now at 40%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 3
# test: we are now at 21%
# 1
# test: we are now at 25%
# 2
# test: we are now at 28%
# 2
# test: we are now at 32%
# 2
# test: we are now at 35%
# 3
# test: we are now at 39%
# 3
# test: we are now at 42%
# 21
# test: we are now at 46%
# 12
# test: we are now at 50%
# 18
# test: we are now at 53%
# 18
# test: we are now at 57%
# 27
# test: we are now at 60%
# 162
# test: we are now at 64%
# 81
# test: we are now at 67%
#  heesch_corona:we are now at 40%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 4
# test: we are now at 27%
# 6
# test: we are now at 31%
# 6
# test: we are now at 34%
# 36
# test: we are now at 37%
# 18
# test: we are now at 41%
# 36
# test: we are now at 44%
# 24
# test: we are now at 48%
# 36
# test: we are now at 51%
#  heesch_corona:we are now at 41%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 2
# test: we are now at 24%
# 4
# test: we are now at 27%
# 6
# test: we are now at 31%
# 6
# test: we are now at 34%
# 36
# test: we are now at 37%
# 18
# test: we are now at 41%
# 36
# test: we are now at 44%
# 24
# test: we are now at 48%
# 36
# test: we are now at 51%
#  heesch_corona:we are now at 41%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
# 4
# test: we are now at 28%
# 6
# test: we are now at 32%
# 6
# test: we are now at 35%
# 36
# test: we are now at 39%
# 18
# test: we are now at 42%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
#  heesch_corona:we are now at 42%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
# 4
# test: we are now at 28%
# 6
# test: we are now at 32%
# 6
# test: we are now at 35%
# 36
# test: we are now at 39%
# 18
# test: we are now at 42%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
#  heesch_corona:we are now at 42%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 4
# test: we are now at 23%
# 4
# test: we are now at 26%
# 4
# test: we are now at 30%
# 6
# test: we are now at 33%
# 6
# test: we are now at 36%
# 36
# test: we are now at 40%
# 18
# test: we are now at 43%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
#  heesch_corona:we are now at 42%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 16%
# 2
# test: we are now at 20%
# 4
# test: we are now at 23%
# 4
# test: we are now at 26%
# 4
# test: we are now at 30%
# 6
# test: we are now at 33%
# 6
# test: we are now at 36%
# 36
# test: we are now at 40%
# 18
# test: we are now at 43%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
#  heesch_corona:we are now at 43%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 4
# test: we are now at 24%
# 4
# test: we are now at 27%
# 4
# test: we are now at 31%
# 6
# test: we are now at 34%
# 6
# test: we are now at 37%
# 36
# test: we are now at 41%
# 18
# test: we are now at 44%
# 36
# test: we are now at 48%
# 24
# test: we are now at 51%
# 36
# test: we are now at 55%
#  heesch_corona:we are now at 43%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 4
# test: we are now at 24%
# 4
# test: we are now at 27%
# 4
# test: we are now at 31%
# 6
# test: we are now at 34%
# 6
# test: we are now at 37%
# 36
# test: we are now at 41%
# 18
# test: we are now at 44%
# 36
# test: we are now at 48%
# 24
# test: we are now at 51%
# 36
# test: we are now at 55%
#  heesch_corona:we are now at 44%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
# 4
# test: we are now at 28%
# 6
# test: we are now at 32%
# 6
# test: we are now at 35%
# 36
# test: we are now at 39%
# 18
# test: we are now at 42%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
# 36
# test: we are now at 57%
# 36
# test: we are now at 60%
# 216
# test: we are now at 64%
# 60
# test: we are now at 67%
# 216
# test: we are now at 71%
# 144
# test: we are now at 75%
# 108
# test: we are now at 78%
# 216
# test: we are now at 82%
# 144
# test: we are now at 85%
# 144
# test: we are now at 89%
# 288
# test: we are now at 92%
# 288
# test: we are now at 96%
# 288
# test: we are now at 100%
# 144
#  heesch_corona:we are now at 44%
# test: we are now at 3%
# 2
# test: we are now at 7%
# 7
# test: we are now at 10%
# 3
# test: we are now at 14%
# 3
# test: we are now at 17%
# 2
# test: we are now at 21%
# 2
# test: we are now at 25%
# 4
# test: we are now at 28%
# 6
# test: we are now at 32%
# 6
# test: we are now at 35%
# 36
# test: we are now at 39%
# 18
# test: we are now at 42%
# 36
# test: we are now at 46%
# 24
# test: we are now at 50%
# 36
# test: we are now at 53%
# 36
# test: we are now at 57%
# 36
# test: we are now at 60%
# 216
# test: we are now at 64%
# 60
# test: we are now at 67%
# 216
# test: we are now at 71%
# 144
# test: we are now at 75%
# 108
# test: we are now at 78%
#  heesch_corona:we are now at 44%
# test: we are now at 3%
# 2
# test: we are now at 6%
# 7
# test: we are now at 10%
# 3
# test: we are now at 13%
# 3
# test: we are now at 17%
# 2
# test: we are now at 20%
# 4
# test: we are now at 24%
# 4
# test: we are now at 27%
# 4
# test: we are now at 31%
# 6
# test: we are now at 34%
# 6
# test: we are now at 37%
# 36
# ...
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 16%
# 8
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 33%
# 8
# test: we are now at 35%
# 12
# test: we are now at 37%
# 34
# test: we are now at 39%
# 18
# test: we are now at 41%
# 18
# test: we are now at 43%
# 24
# test: we are now at 45%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 16%
# 8
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 33%
# 8
# test: we are now at 35%
# 12
# test: we are now at 37%
# 34
# test: we are now at 39%
# 18
# test: we are now at 41%
# 18
# test: we are now at 43%
# 24
# test: we are now at 45%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 27%
# 12
# test: we are now at 29%
# 14
# test: we are now at 31%
# 10
# test: we are now at 33%
# 6
# test: we are now at 35%
# 8
# test: we are now at 37%
# 12
# test: we are now at 39%
# 34
# test: we are now at 41%
# 18
# test: we are now at 43%
# 18
# test: we are now at 45%
# 24
# test: we are now at 47%
# 24
# test: we are now at 49%
# 24
# test: we are now at 50%
# 144
# test: we are now at 52%
# 72
# test: we are now at 54%
# 192
# test: we are now at 56%
# 144
# test: we are now at 58%
# 216
# test: we are now at 60%
# 216
# test: we are now at 62%
# 144
# test: we are now at 64%
# 144
# test: we are now at 66%
# 144
# test: we are now at 68%
# 144
# test: we are now at 70%
# 216
# test: we are now at 72%
# 216
# test: we are now at 74%
# 216
# test: we are now at 76%
# 216
# test: we are now at 78%
# 144
# test: we are now at 80%
# 144
# test: we are now at 82%
# 144
# test: we are now at 84%
# 144
# test: we are now at 86%
# 144
# test: we are now at 88%
# 288
# test: we are now at 90%
# 288
# test: we are now at 92%
# 288
# test: we are now at 94%
# 288
# test: we are now at 96%
# 288
# test: we are now at 98%
# 432
# test: we are now at 100%
# 432
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 27%
# 12
# test: we are now at 29%
# 14
# test: we are now at 31%
# 10
# test: we are now at 33%
# 6
# test: we are now at 35%
# 8
# test: we are now at 37%
# 12
# test: we are now at 39%
# 34
# test: we are now at 41%
# 18
# test: we are now at 43%
# 18
# test: we are now at 45%
# 24
# test: we are now at 47%
# 24
# test: we are now at 49%
# 24
# test: we are now at 50%
# 144
# test: we are now at 52%
# 72
# test: we are now at 54%
# 192
# test: we are now at 56%
# 144
# test: we are now at 58%
# 216
# test: we are now at 60%
# 216
# test: we are now at 62%
# 144
# test: we are now at 64%
# 144
# test: we are now at 66%
# 144
# test: we are now at 68%
# 144
# test: we are now at 70%
# 216
# test: we are now at 72%
# 216
# test: we are now at 74%
# 216
# test: we are now at 76%
# 216
# test: we are now at 78%
# 144
# test: we are now at 80%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
# 24
# test: we are now at 48%
# 24
# test: we are now at 50%
# 144
# test: we are now at 51%
# 72
# test: we are now at 53%
# 120
# test: we are now at 55%
# 72
# test: we are now at 57%
# 48
# test: we are now at 59%
# 24
# test: we are now at 61%
# 24
# test: we are now at 63%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
# 24
# test: we are now at 48%
# 24
# test: we are now at 50%
# 144
# test: we are now at 51%
# 72
# test: we are now at 53%
# 120
# test: we are now at 55%
# 72
# test: we are now at 57%
# 48
# test: we are now at 59%
# 24
# test: we are now at 61%
# 24
# test: we are now at 63%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
# 24
# test: we are now at 48%
# 24
# test: we are now at 50%
# 144
# test: we are now at 51%
# 72
# test: we are now at 53%
# 120
# test: we are now at 55%
# 72
# test: we are now at 57%
# 48
# test: we are now at 59%
# 72
# test: we are now at 61%
# 72
# test: we are now at 63%
# 96
# test: we are now at 65%
# 144
# test: we are now at 67%
# 144
# test: we are now at 69%
# 216
# test: we are now at 71%
# 216
# test: we are now at 73%
# 216
# test: we are now at 75%
# 288
# test: we are now at 76%
# 288
# test: we are now at 78%
# 288
# test: we are now at 80%
# 576
# test: we are now at 82%
# 576
# test: we are now at 84%
# 576
# test: we are now at 86%
# 576
# test: we are now at 88%
# 1152
# test: we are now at 90%
# 1152
# test: we are now at 92%
# 1152
# test: we are now at 94%
# 1152
# test: we are now at 96%
# 1152
# test: we are now at 98%
# 1728
# test: we are now at 100%
# 1728
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 12
# test: we are now at 15%
# 2
# test: we are now at 17%
# 8
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 4
# test: we are now at 25%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 14
# test: we are now at 30%
# 10
# test: we are now at 32%
# 6
# test: we are now at 34%
# 8
# test: we are now at 36%
# 12
# test: we are now at 38%
# 34
# test: we are now at 40%
# 18
# test: we are now at 42%
# 18
# test: we are now at 44%
# 24
# test: we are now at 46%
# 24
# test: we are now at 48%
# 24
# test: we are now at 50%
# 144
# test: we are now at 51%
# 72
# test: we are now at 53%
# 120
# test: we are now at 55%
# 72
# test: we are now at 57%
# 48
# test: we are now at 59%
# 72
# test: we are now at 61%
# 72
# test: we are now at 63%
# 96
# test: we are now at 65%
# 144
# test: we are now at 67%
# 144
# test: we are now at 69%
# 216
# test: we are now at 71%
# 216
# test: we are now at 73%
# 216
# test: we are now at 75%
# 288
# test: we are now at 76%
# 288
# test: we are now at 78%
# 288
# test: we are now at 80%
#  heesch_corona:we are now at 1%
# test: we are now at 2%
# 2
# test: we are now at 4%
# 7
# test: we are now at 6%
# 3
# test: we are now at 8%
# 3
# test: we are now at 10%
# 2
# test: we are now at 12%
# 2
# test: we are now at 14%
# 4
# test: we are now at 16%
# 4
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 24
# test: we are now at 30%
# 16
# test: we are now at 32%
# 24
# test: we are now at 34%
# 24
# test: we are now at 36%
# 12
# test: we are now at 38%
# 12
# test: we are now at 40%
# 12
# test: we are now at 42%
# 12
# test: we are now at 44%
#  heesch_corona:we are now at 1%
# test: we are now at 2%
# 2
# test: we are now at 4%
# 7
# test: we are now at 6%
# 3
# test: we are now at 8%
# 3
# test: we are now at 10%
# 2
# test: we are now at 12%
# 2
# test: we are now at 14%
# 4
# test: we are now at 16%
# 4
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 24
# test: we are now at 30%
# 16
# test: we are now at 32%
# 24
# test: we are now at 34%
# 24
# test: we are now at 36%
# 12
# test: we are now at 38%
# 12
# test: we are now at 40%
# 12
# test: we are now at 42%
# 12
# test: we are now at 44%
#  heesch_corona:we are now at 1%
# test: we are now at 2%
# 2
# test: we are now at 4%
# 7
# test: we are now at 6%
# 3
# test: we are now at 8%
# 3
# test: we are now at 10%
# 2
# test: we are now at 12%
# 2
# test: we are now at 14%
# 4
# test: we are now at 16%
# 4
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 24
# test: we are now at 30%
# 16
# test: we are now at 32%
# 24
# test: we are now at 34%
# 24
# test: we are now at 36%
# 12
# test: we are now at 38%
# 12
# test: we are now at 40%
# 12
# test: we are now at 42%
# 12
# test: we are now at 44%
#  heesch_corona:we are now at 1%
# test: we are now at 2%
# 2
# test: we are now at 4%
# 7
# test: we are now at 6%
# 3
# test: we are now at 8%
# 3
# test: we are now at 10%
# 2
# test: we are now at 12%
# 2
# test: we are now at 14%
# 4
# test: we are now at 16%
# 4
# test: we are now at 18%
# 4
# test: we are now at 20%
# 4
# test: we are now at 22%
# 4
# test: we are now at 24%
# 24
# test: we are now at 26%
# 12
# test: we are now at 28%
# 24
# test: we are now at 30%
# 16
# test: we are now at 32%
# 24
# test: we are now at 34%
# 24
# test: we are now at 36%
# 12
# test: we are now at 38%
# 12
# test: we are now at 40%
# 12
# test: we are now at 42%
# 12
# test: we are now at 44%
#  heesch_corona:we are now at 1%
# test: we are now at 1%
# 2
# test: we are now at 3%
# 7
# test: we are now at 5%
# 3
# test: we are now at 7%
# 3
# test: we are now at 9%
# 2
# test: we are now at 11%
# 2
# test: we are now at 13%
# 4
# test: we are now at 15%
# 4
# test: we are now at 17%
# 4
# test: we are now at 19%
# 4
# test: we are now at 21%
# 4
# test: we are now at 23%
# 24
# test: we are now at 25%
# 12
# test: we are now at 27%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 110
#     100 # S1 = HShape( [Hexagon(0,0), Hexagon(2,1), Hexagon(3,0)])
#     101 # S1 = HShape( [hex for hex in bhmaker(0,0) if hex not in [Hexagon(-2,-1), Hexagon(0,0)] ]  )
#     102 # S1 = HShape( bhmaker(0,0)+[Hexagon(-2,2), Hexagon(-2,-4), Hexagon(4,2), Hexagon(0,-3), Hexagon(3,0), Hexagon(4,-1)] )
#     105 """ This has types:
#     106     1) Corona
#     107     2) Boundary
#     108     3) Base
#     109 """
# --> 110 data_writer(S1, type = "heesch")
#     111 print("--- %s seconds ---" % (time.time() - start_time))
#
# Cell In[1], line 11, in data_writer(base, type)
#       9 with open('./plotlist.txthexagon testing-1', 'w') as file:
#      10     if type == "heesch":
# ---> 11         coronalist = base.heesch_computer()[0]
#      12         coronadata = []
#      13         for corona_config in coronalist:
#
# File c:\Users\tk\Desktop\2024第十三届认证杯数学中国数学建模国际赛（小美赛）赛题\code\heesch_number_computer-main\heesch_number_computer-main\code\hexshapes.py:296, in HShape.heesch_computer(self)
#     290 message = f"""
#     291 --------------------------------------
#     292 We are now computing the {i+2}nd corona
#     293 --------------------------------------
#     294 """
#     295 print(message)
# --> 296 new_corona_list = self.heesch_corona(coronalist)
#     297 if new_corona_list == []:
#     298     print(f" The heesch number is {i+1}")
#
# File c:\Users\tk\Desktop\2024第十三届认证杯数学中国数学建模国际赛（小美赛）赛题\code\heesch_number_computer-main\heesch_number_computer-main\code\hexshapes.py:275, in HShape.heesch_corona(self, coronalist)
#     273         ns_hexes.extend(shape.hexes)
#     274 new_shape = HShape(ns_hexes)
# --> 275 new_corona = new_shape.corona_maker(self.orientations())
#     277 for elem in new_corona:
#     278     new_corona_config = corona_config.copy()
#
# File c:\Users\tk\Desktop\2024第十三届认证杯数学中国数学建模国际赛（小美赛）赛题\code\heesch_number_computer-main\heesch_number_computer-main\code\hexshapes.py:227, in HShape.corona_maker(self, base_orientations, bookkeeping, heesch)
#     225 for ns_hex in base_orientations[index].hexes:
#     226     new_shape = base_orientations[index].translate_rel(outs_hex, ns_hex)
# --> 227     if all(not_occupied_in(hex, config, extra=True) for hex in new_shape.hexes) and edge_filter(new_shape.edges, config_edgemaker(config)):
#     228         new_config = config.copy()
#     229         new_config.append(new_shape)
#
# File c:\Users\tk\Desktop\2024第十三届认证杯数学中国数学建模国际赛（小美赛）赛题\code\heesch_number_computer-main\heesch_number_computer-main\code\hexshapes.py:201, in HShape.corona_maker.<locals>.config_edgemaker(config)
#     199 def config_edgemaker(config):  # 生成配置的边
#     200     hexes_edge_list = [edge for shape in config+[self] for edge in shape.edges]
# --> 201     total_edge_list = [edge for edge in hexes_edge_list if hexes_edge_list.count(edge) == 1]
#     202     return total_edge_list
#
# KeyboardInterrupt:

# %%
from hexshapes import Hexagon, HShape
import ast
import matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon, Circle

import numpy as np

def parametrization(el):
    xcoord = el[0]-0.5 * el[1]
    ycoord = 0.5*np.sqrt(3)*el[1]
    return (xcoord, ycoord)

def shapedrawer(shape, axes, color):
    for hex in shape.hexes:
        hexagon = RegularPolygon(parametrization(hex.origin), numVertices=6, orientation = 1/6 *np.pi ,radius= 1, alpha=1, color= color)
        axes.add_patch(hexagon)
        edgedata = hex.edgedata
        for i in range(len(edgedata)):
            if edgedata[i] == 1:
                coord = parametrization(hex.origin)
                coord = (coord[0]+2/3*np.cos(i*1/6*2*np.pi-1/2*np.pi), coord[1]+2/3*np.sin(i*1/6*2*np.pi-1/2*np.pi))
                circle = Circle(coord, radius = 1/16, color="k")
                axes.add_patch(circle)
            elif edgedata[i] == -1:
                coord = parametrization(hex.origin)
                coord = (coord[0]+2/3*np.cos(i*1/6*2*np.pi-1/2*np.pi), coord[1]+2/3*np.sin(i*1/6*2*np.pi-1/2*np.pi))
                circle = Circle(coord, radius = 1/16, color="w")
                axes.add_patch(circle)
with open('./plotlist.txthexagon testing-1', 'r') as text:
    data = ast.literal_eval(text.readline())

axs = plt.subplot()
plottinglist = []
if data["type"] == "base":
    base = HShape( [Hexagon(*elem) for elem in data["data"]["base"]])
    shapedrawer(base, axs, "thistle")
    plottinglist.extend(base.plot_data("k"))

elif data["type"] == "corona":
    config = data["data"]["corona"]
    for pre_shape in config:
        shape = HShape( [Hexagon(*elem) for elem in pre_shape] )
        shapedrawer(shape, axs, "lightseagreen")
        plottinglist.extend(shape.plot_data("k"))
    base = HShape( [Hexagon(*elem) for elem in data["data"]["base"]])
    shapedrawer(base, axs, "turquoise")
    plottinglist.extend(base.plot_data("k"))

elif data["type"] == "heesch":
    heesch_data = data["data"]["heesch"]
    for index in range(len(heesch_data)):
        corona = heesch_data[index]
        for pre_shape in corona:
            shape = HShape( [Hexagon(*elem) for elem in pre_shape] )
            color = "lightseagreen" if index%2 == 0 else "aquamarine"
            shapedrawer(shape, axs, color)
            plottinglist.extend(shape.plot_data("k"))

    base = HShape( [Hexagon(*elem) for elem in data["data"]["base"]])
    shapedrawer(base, axs, "aquamarine")
    plottinglist.extend(base.plot_data("k"))

elif data["type"] == "corona2":
    first = data["data"]["first"]
    for pre_shape in first:
        shape = HShape( [Hexagon(*elem) for elem in pre_shape] )
        shapedrawer(shape, axs, "lightseagreen")
        plottinglist.extend(shape.plot_data("k"))

    second = data["data"]["second"]
    for pre_shape in second:
        shape = HShape( [Hexagon(*elem) for elem in pre_shape] )
        shapedrawer(shape, axs, "turquoise")
        plottinglist.extend(shape.plot_data("k"))

    base = HShape( [Hexagon(*elem) for elem in data["data"]["base"]])
    shapedrawer(base, axs, "aquamarine")
    plottinglist.extend(base.plot_data("k"))


axs.plot(*(plottinglist), linewidth=0.3)
plt.autoscale(enable = True)
axs.set_aspect("equal")
plt.axis('off')
plt.show()
