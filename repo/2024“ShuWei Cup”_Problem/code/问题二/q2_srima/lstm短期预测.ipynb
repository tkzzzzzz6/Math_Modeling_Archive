# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# 设置matplotlib使用支持中文的字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 加载数据
data = pd.read_excel('Attachment 1.xlsx')
data.columns = ['MJD(days)', 'PT-TT(s)']

# 设置MJD(days)为索引
data.set_index(keys='MJD(days)', inplace=True)

# 清理数据，将非数值转换为NaN并删除
data['PT-TT(s)'] = pd.to_numeric(data['PT-TT(s)'], errors='coerce')
data = data.dropna()

# 数据标准化
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data['PT-TT(s)'].values.reshape(-1, 1))

# 准备LSTM的输入数据
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

# 增加序列长度以捕捉更长期的模式
seq_length = 90  # 从30增加到90天
X, y = create_sequences(scaled_data, seq_length)

# 划分训练集和测试集
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 重塑数据以适应LSTM输入格式 [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# 构建更复杂的双向LSTM模型
model = Sequential([
    Bidirectional(LSTM(200, activation='relu', return_sequences=True), input_shape=(seq_length, 1)),
    Dropout(0.3),
    Bidirectional(LSTM(150, activation='relu', return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(100, activation='relu')),
    Dropout(0.3),
    Dense(50, activation='relu'),
    Dense(1)
])

# 编译模型，使用更小的学习率以提高稳定性
model.compile(optimizer=Adam(learning_rate=0.0005), loss='mse')

# 训练模型，增加epochs
history = model.fit(X_train, y_train, epochs=200, batch_size=32, 
                   validation_split=0.1, verbose=1)

# 预测未来30天
last_sequence = scaled_data[-seq_length:]
predictions = []

for _ in range(30):
    # 重塑数据用于预测
    current_sequence = last_sequence.reshape(1, seq_length, 1)
    # 预测下一个值
    next_pred = model.predict(current_sequence, verbose=0)[0]
    # 确保预测值在[0,1]范围内
    next_pred = np.clip(next_pred, 0, 1)
    # 添加预测值到列表
    predictions.append(next_pred[0])
    # 更新序列
    last_sequence = np.append(last_sequence[1:], next_pred)

# 反向转换预测值
predictions = np.array(predictions).reshape(-1, 1)
predictions = np.clip(predictions, 0, 1)  # 再次确保所有值都在[0,1]范围内
predictions = scaler.inverse_transform(predictions)

# 创建预测索引
forecast_index = data.index[-1] + np.arange(1, 31)

# 保存预测结果
forecast_df = pd.DataFrame({
    'MJD(days)': forecast_index,
    'Predicted PT-TT(s)': predictions.flatten()
})
forecast_df.to_csv('LSTM短期预测结果.csv', index=False, encoding='utf-8-sig')

# 绘制结果
plt.figure(figsize=(12, 8))
plt.plot(data['PT-TT(s)'], label='历史噪声数据', color='blue', linewidth=2)
plt.plot(forecast_index, predictions, label='LSTM短期预测（30天）', color='red', linestyle='--', linewidth=2)
plt.xlabel('MJD(days)')
plt.ylabel('PT-TT(s)')
plt.title('脉冲星计时噪声的LSTM短期预测')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Epoch 1/200
# C:\Users\tk\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - loss: 0.1477 - val_loss: 0.0249
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 0.0297 - val_loss: 0.0152
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0101 - val_loss: 0.0028
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 0.0074 - val_loss: 0.0011
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.0044 - val_loss: 0.0021
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.0045 - val_loss: 3.3338e-04
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - loss: 0.0045 - val_loss: 2.8615e-04
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - loss: 0.0038 - val_loss: 2.1846e-04
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - loss: 0.0034 - val_loss: 2.8249e-04
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - loss: 0.0030 - val_loss: 2.5406e-04
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - loss: 0.0031 - val_loss: 3.5008e-04
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 0.0022 - val_loss: 2.1843e-04
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0026 - val_loss: 2.3868e-04
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 0.0035 - val_loss: 4.0225e-04
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - loss: 0.0027 - val_loss: 1.6316e-04
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0026 - val_loss: 3.2259e-04
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0022 - val_loss: 1.5538e-04
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0026 - val_loss: 2.5895e-04
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - loss: 0.0024 - val_loss: 1.6601e-04
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 0.0026 - val_loss: 1.6596e-04
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.0027 - val_loss: 1.4526e-04
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0023 - val_loss: 7.3365e-04
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0022 - val_loss: 4.2234e-04
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - loss: 0.0019 - val_loss: 4.1280e-04
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 0.0020 - val_loss: 1.2750e-04
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0016 - val_loss: 2.6447e-04
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0020 - val_loss: 5.4455e-04
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - loss: 0.0019 - val_loss: 1.9288e-04
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 0.0016 - val_loss: 5.1440e-04
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0022 - val_loss: 1.3965e-04
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0016 - val_loss: 1.0536e-04
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 0.0019 - val_loss: 1.0385e-04
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0014 - val_loss: 2.6958e-04
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 0.0014 - val_loss: 1.4153e-04
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0014 - val_loss: 3.2029e-04
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0014 - val_loss: 1.1002e-04
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.0018 - val_loss: 6.0186e-04
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.0018 - val_loss: 7.9391e-04
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0015 - val_loss: 6.7395e-04
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0020 - val_loss: 3.0788e-04
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.0016 - val_loss: 2.2385e-04
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0014 - val_loss: 1.2317e-04
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0015 - val_loss: 1.1578e-04
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0012 - val_loss: 7.5351e-05
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0013 - val_loss: 8.5691e-05
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - loss: 0.0013 - val_loss: 1.3348e-04
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.0014 - val_loss: 2.5822e-04
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0016 - val_loss: 4.6179e-04
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - loss: 0.0013 - val_loss: 1.7896e-04
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0014 - val_loss: 1.4885e-04
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0012 - val_loss: 1.1233e-04
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 0.0013 - val_loss: 7.4494e-05
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.0013 - val_loss: 2.8900e-04
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.0012 - val_loss: 3.1680e-04
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0011 - val_loss: 2.9670e-04
# Epoch 60/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0011 - val_loss: 9.2713e-05
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0016 - val_loss: 8.7430e-04
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 0.0015 - val_loss: 2.1401e-04
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.0015 - val_loss: 1.9539e-04
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0014 - val_loss: 1.5155e-04
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.0013 - val_loss: 1.8191e-04
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.0017 - val_loss: 2.2943e-04
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.0016 - val_loss: 1.4217e-04
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 0.0011 - val_loss: 2.6219e-04
# Epoch 70/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.0013 - val_loss: 1.3482e-04
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 0.0012 - val_loss: 1.0889e-04
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.0010 - val_loss: 4.6185e-04
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 9.3464e-04 - val_loss: 7.3485e-05
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0011 - val_loss: 3.7408e-04
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0012 - val_loss: 4.0327e-04
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.0012 - val_loss: 8.3388e-05
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.0010 - val_loss: 1.6671e-04
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.0010 - val_loss: 2.3881e-04
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 0.0010 - val_loss: 4.2285e-04
# Epoch 80/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0011 - val_loss: 1.2871e-04
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.0015 - val_loss: 7.8018e-05
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0011 - val_loss: 6.2040e-05
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 7.3059e-04 - val_loss: 5.4853e-05
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 9.3974e-04 - val_loss: 4.2847e-04
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 8.8147e-04 - val_loss: 2.8349e-04
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0011 - val_loss: 1.1126e-04
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 9.6143e-04 - val_loss: 8.7419e-05
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 7.0793e-04 - val_loss: 3.0719e-04
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 8.3176e-04 - val_loss: 7.1886e-05
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 9.3873e-04 - val_loss: 5.4859e-05
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 8.2300e-04 - val_loss: 2.3893e-04
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0011 - val_loss: 1.4169e-04
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0011 - val_loss: 9.4805e-05
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 6.4407e-04 - val_loss: 1.7391e-04
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 9.7203e-04 - val_loss: 8.3241e-05
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 6.4490e-04 - val_loss: 7.8677e-05
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.2876e-04 - val_loss: 8.8640e-04
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.0012 - val_loss: 7.1133e-05
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 9.9049e-04 - val_loss: 4.8675e-05
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 9.3949e-04 - val_loss: 1.6104e-04
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0013 - val_loss: 5.2061e-04
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0011 - val_loss: 1.2917e-04
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 8.1733e-04 - val_loss: 3.8304e-04
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 7.8679e-04 - val_loss: 9.7169e-05
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 8.1968e-04 - val_loss: 9.0506e-05
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - loss: 7.7438e-04 - val_loss: 1.1088e-04
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 6.4983e-04 - val_loss: 5.8177e-04
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 9.0031e-04 - val_loss: 7.5104e-05
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 6.8045e-04 - val_loss: 5.2520e-04
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 7.2091e-04 - val_loss: 7.3395e-05
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 7.4872e-04 - val_loss: 2.6325e-04
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 7.7241e-04 - val_loss: 1.7775e-04
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 7.4563e-04 - val_loss: 2.8708e-04
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 8.8357e-04 - val_loss: 5.6275e-04
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 7.5343e-04 - val_loss: 3.6718e-04
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 6.3661e-04 - val_loss: 1.0361e-04
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 7.4015e-04 - val_loss: 1.0624e-04
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 8.0041e-04 - val_loss: 1.2380e-04
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 7.6158e-04 - val_loss: 1.3827e-04
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 6.7236e-04 - val_loss: 7.2775e-05
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 7.5900e-04 - val_loss: 8.9662e-05
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 7.0932e-04 - val_loss: 1.0136e-04
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 7.6613e-04 - val_loss: 2.1611e-04
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 9.8973e-04 - val_loss: 7.6545e-04
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 7.9524e-04 - val_loss: 7.9346e-05
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 7.6891e-04 - val_loss: 9.0469e-05
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 5.8240e-04 - val_loss: 3.6438e-04
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 7.1217e-04 - val_loss: 1.1455e-04
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 4.9384e-04 - val_loss: 9.5162e-05
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 4.9057e-04 - val_loss: 8.3190e-05
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 5.5310e-04 - val_loss: 4.8329e-04
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 8.3858e-04 - val_loss: 1.8523e-04
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 5.3499e-04 - val_loss: 9.9949e-05
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 5.4050e-04 - val_loss: 2.9527e-04
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 6.4051e-04 - val_loss: 1.7448e-04
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 6.5720e-04 - val_loss: 2.9603e-04
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 5.8436e-04 - val_loss: 1.0681e-04
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 7.3117e-04 - val_loss: 1.1913e-04
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 4.6608e-04 - val_loss: 2.4022e-04
# Epoch 140/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 5.3894e-04 - val_loss: 1.3205e-04
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 7.0694e-04 - val_loss: 1.4932e-04
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 6.9561e-04 - val_loss: 9.9797e-05
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 4.5099e-04 - val_loss: 6.6786e-05
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 6.5344e-04 - val_loss: 1.6477e-04
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 6.4285e-04 - val_loss: 9.2196e-05
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 5.8062e-04 - val_loss: 9.0537e-05
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 7.5047e-04 - val_loss: 8.2973e-05
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 5.4576e-04 - val_loss: 1.7692e-04
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 4.5301e-04 - val_loss: 1.4898e-04
# Epoch 150/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 4.8802e-04 - val_loss: 7.0308e-05
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 4.9230e-04 - val_loss: 1.1608e-04
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 5.5420e-04 - val_loss: 1.1391e-04
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 5.8431e-04 - val_loss: 2.2393e-04
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 5.6374e-04 - val_loss: 1.2285e-04
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 5.8019e-04 - val_loss: 1.8995e-04
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 5.3426e-04 - val_loss: 8.1623e-04
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 7.4331e-04 - val_loss: 1.8867e-04
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 6.9646e-04 - val_loss: 2.0140e-04
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 6.3320e-04 - val_loss: 1.2698e-04
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 5.5837e-04 - val_loss: 1.2549e-04
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 5.0341e-04 - val_loss: 2.5831e-04
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 5.9550e-04 - val_loss: 2.1342e-04
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 6.1381e-04 - val_loss: 9.2038e-05
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 5.6358e-04 - val_loss: 8.2450e-05
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 5.6341e-04 - val_loss: 9.0867e-05
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 5.0577e-04 - val_loss: 2.8661e-04
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 6.1082e-04 - val_loss: 8.8218e-05
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 4.3799e-04 - val_loss: 1.0913e-04
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 5.2042e-04 - val_loss: 1.4790e-04
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 4.6212e-04 - val_loss: 2.4258e-04
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 4.8615e-04 - val_loss: 1.1343e-04
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 4.9937e-04 - val_loss: 4.4693e-04
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 5.0100e-04 - val_loss: 1.6783e-04
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 4.9202e-04 - val_loss: 3.3092e-04
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - loss: 6.0375e-04 - val_loss: 1.5286e-04
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step - loss: 4.8562e-04 - val_loss: 1.3153e-04
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 4.2401e-04 - val_loss: 1.2724e-04
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 6.1606e-04 - val_loss: 8.4514e-05
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 225ms/step - loss: 4.8615e-04 - val_loss: 1.0210e-04
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 5.3557e-04 - val_loss: 1.7249e-04
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 4.4017e-04 - val_loss: 1.2782e-04
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 5.3479e-04 - val_loss: 8.0669e-05
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 4.4682e-04 - val_loss: 1.6462e-04
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 3.8907e-04 - val_loss: 1.8027e-04
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 3.8078e-04 - val_loss: 8.3906e-05
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 4.3952e-04 - val_loss: 8.2344e-05
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 4.6654e-04 - val_loss: 2.0065e-04
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 4.2449e-04 - val_loss: 2.0770e-04
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 6.9129e-04 - val_loss: 9.1488e-05
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 4.5358e-04 - val_loss: 1.1567e-04
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 4.4243e-04 - val_loss: 7.6812e-05
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 4.6300e-04 - val_loss: 9.7650e-05
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 3.9854e-04 - val_loss: 1.0453e-04
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 3.4849e-04 - val_loss: 8.5236e-05
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 4.4842e-04 - val_loss: 1.5425e-04
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 3.5856e-04 - val_loss: 3.9383e-04
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 4.4308e-04 - val_loss: 8.8430e-05
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 3.8186e-04 - val_loss: 2.5842e-04
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: 6.8535e-04 - val_loss: 1.8231e-04
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - loss: 3.7550e-04 - val_loss: 7.4301e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
#
# Diebold-Mariano检验结果:
# DM统计量: 4.0112
# p值: 0.0001
# LSTM模型的预测能力显著优于基准模型
